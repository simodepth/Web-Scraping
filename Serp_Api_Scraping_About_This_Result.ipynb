# %% [markdown]
# <a href="https://colab.research.google.com/github/simodepth/Web-Scraping/blob/main/Serp_Api_Scraping_About_This_Result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-search-results
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.1-py3-none-any.whl size=25789 sha256=9eab92d2aa00d8878657e060ec63ca3755c6a5512168080f6e7c350fe830ba97
#   Stored in directory: /root/.cache/pip/wheels/82/a3/c5/364155118f298722dff2f79ae4dd7c91e92b433ad36d6f7e0e
# Successfully built google-search-results
# ...

# %%
from serpapi import GoogleSearch
import pandas as pd

params = {
  "engine": "google_about_this_result",
  "q": "About https://www.starbucks.com/",
  "ilps": "ADNMCi0cMyV0H7KdBl4d_vac7u0R1ouGYg",
  "api_key": "fbb0564d15451bc375ec75f75bab1db3ae1a4775682e6c07ec8c685099506cb0"
}

search = GoogleSearch(params)
results = search.get_dict()
about_this_result = results['about_this_result']


# access "organic results"
df = pd.DataFrame(results['about_this_result'])
df
# Out:
# https://serpapi.com/search
#                                                  title  \
# title                         Starbucks Coffee Company
# subtitle                      Starbucks Coffee Company
# description                   Starbucks Coffee Company
# in_their_own_words            Starbucks Coffee Company
# site_first_indexed_by_google  Starbucks Coffee Company
# web_results_about_the_source  Starbucks Coffee Company
# related_results               Starbucks Coffee Company
#
#                                                     link  \
# title                         https://www.starbucks.com/
# subtitle                      https://www.starbucks.com/
# description                   https://www.starbucks.com/
# in_their_own_words            https://www.starbucks.com/
# site_first_indexed_by_google  https://www.starbucks.com/
# web_results_about_the_source  https://www.starbucks.com/
# related_results               https://www.starbucks.com/
#
# ...

# %%
df.to_csv('about_this_result')

# %%
#@title Data Cleaning

#remove special characters from values
Data = pd.read_csv('/content/about_this_result')
Data['about_the_source'] =  Data['about_the_source'].str.replace(".?{'snippet':|}|{'title':|'|\[|\]", "")
Data['about_the_topic'] =  Data['about_the_topic'].str.replace(".?{'snippet':|}|{'title':|'|\[|\]", "")
Data = Data.drop(['title','link','displayed_link','favicon'], axis=1)
cols = ['Index', 'About the Source','About the Topic']
Data.columns = cols

#fill NaN value 
Data = Data.fillna(0)
Data.isnull().sum()
Data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#                           Index  \
# 0                         title
# 1                      subtitle
# 2                   description
# 3            in_their_own_words
# 4  site_first_indexed_by_google
# 5  web_results_about_the_source
# 6               related_results
#
#                                     About the Source  \
# 0                                          Starbucks
# 1                                Coffeehouse company
# 2   "Starbucks Corporation is an American multina...
# 3   "Our story begins in 1971 along the cobblesto...
# 4                             More than 10 years ago
# 5   Starbucks Reviews - 191 Reviews of Starbucks....
# ...
